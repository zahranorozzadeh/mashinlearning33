# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('OnlineRetail.csv', encoding='latin1')
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

data['InvoiceYearMonth'] = data['InvoiceDate'].map(lambda date: 100*date.year + date.month)

data['Revenue'] = data['UnitPrice'] * data['Quantity']
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#    InvoiceYearMonth  Revenue
# 0            201012    15.30
# 1            201012    20.34
# 2            201012    22.00
# 3            201012    20.34
# 4            201012    20.34

# %%
tx_revenue = data.groupby(['InvoiceYearMonth'])['Revenue'].sum().reset_index()
tx_revenue
# Out:
#     InvoiceYearMonth      Revenue
# 0             201012   748957.020
# 1             201101   560000.260
# 2             201102   498062.650
# 3             201103   683267.080
# 4             201104   493207.121
# 5             201105   723333.510
# 6             201106   691123.120
# 7             201107   681300.111
# 8             201108   682680.510
# 9             201109  1019687.622
# 10            201110  1070704.670
# 11            201111  1461756.250
# 12            201112   433668.010

# %%
plt.scatter(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'])

# %%
plt.plot(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'])

# %%
plt.plot(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'])
plt.scatter(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'])

# %%
plt.plot(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'],marker='o')

# %%
plt.plot(tx_revenue['InvoiceYearMonth'],tx_revenue['Revenue'],marker='o')
plt.grid()

# %%
plt.plot(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str),tx_revenue['Revenue'],marker='o')
plt.grid()

# %%
plt.figure(figsize=(12,6))
plt.plot(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str),tx_revenue['Revenue'],marker='o')
plt.grid()

# %%
tx_revenue['MonthlyGrowth'] = tx_revenue['Revenue'].pct_change()
tx_revenue.head(10)
# Out:
#    InvoiceYearMonth      Revenue  MonthlyGrowth
# 0            201012   748957.020            NaN
# 1            201101   560000.260      -0.252293
# 2            201102   498062.650      -0.110603
# 3            201103   683267.080       0.371850
# 4            201104   493207.121      -0.278163
# 5            201105   723333.510       0.466592
# 6            201106   691123.120      -0.044530
# 7            201107   681300.111      -0.014213
# 8            201108   682680.510       0.002026
# 9            201109  1019687.622       0.493653

# %%
plt.figure(figsize=(12,6))

plt.plot(tx_revenue.query("InvoiceYearMonth < 201112")['InvoiceYearMonth'].to_numpy(dtype=str),tx_revenue.query("InvoiceYearMonth < 201112")['MonthlyGrowth'],marker='o')
plt.grid()

# %%
tx_uk = data.query("Country=='United Kingdom'").reset_index(drop=True)
tx_monthly_active = tx_uk.groupby('InvoiceYearMonth')['CustomerID'].nunique().reset_index()

tx_monthly_active.head(10)
# Out:
#    InvoiceYearMonth  CustomerID
# 0            201012         871
# 1            201101         684
# 2            201102         714
# 3            201103         923
# 4            201104         817
# 5            201105         985
# 6            201106         943
# 7            201107         899
# 8            201108         867
# 9            201109        1177

# %%
plt.figure(figsize=(12,6))
plt.plot(tx_revenue['InvoiceYearMonth'])
plt.grid()

# %%
tx_monthly_sales = tx_uk.groupby('InvoiceYearMonth')['Quantity'].sum().reset_index()

tx_monthly_sales.head()
# Out:
#    InvoiceYearMonth  Quantity
# 0            201012    298101
# 1            201101    237381
# 2            201102    225641
# 3            201103    279843
# 4            201104    257666

# %%
plt.figure(figsize=(12,6))
plt.bar(tx_monthly_sales['InvoiceYearMonth'].to_numpy(dtype=str),tx_monthly_sales['Quantity'])
plt.grid()

# %%
tx_min_purchase = tx_uk.groupby('CustomerID').InvoiceDate.min().reset_index()
tx_min_purchase.columns = ['CustomerID','MinPurchaseDate']
tx_min_purchase['MinPurchaseYearMonth'] = tx_min_purchase['MinPurchaseDate'].map(lambda date: 100*date.year + date.month)
tx_uk = pd.merge(tx_uk, tx_min_purchase, on='CustomerID')
tx_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#    InvoiceYearMonth  Revenue     MinPurchaseDate  MinPurchaseYearMonth
# 0            201012    15.30 2010-12-01 08:26:00                201012
# 1            201012    20.34 2010-12-01 08:26:00                201012
# 2            201012    22.00 2010-12-01 08:26:00                201012
# 3            201012    20.34 2010-12-01 08:26:00                201012
# 4            201012    20.34 2010-12-01 08:26:00                201012

# %%
tx_uk['UserType'] = 'New'
tx_uk.loc[tx_uk['InvoiceYearMonth']>tx_uk['MinPurchaseYearMonth'],'UserType'] = 'Existing'
tx_uk.head(500)
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 495    571185     23397          FOOT STOOL HOME SWEET HOME          2
# 496    571185     23096                      PETIT TRAY CHIC        12
# 497    571185     23487             SWEET HEART CAKE CARRIER         2
# 498    571185     23109           PACK OF SIX LED TEA LIGHTS        12
# 499    571185     23434     3 RAFFIA RIBBONS 50'S CHRISTMAS         10
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# 0   2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2   2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ..                  ...        ...         ...             ...
# 495 2011-10-14 11:15:00       9.95     13047.0  United Kingdom
# 496 2011-10-14 11:15:00       1.65     13047.0  United Kingdom
# 497 2011-10-14 11:15:00       9.95     13047.0  United Kingdom
# 498 2011-10-14 11:15:00       2.89     13047.0  United Kingdom
# 499 2011-10-14 11:15:00       0.79     13047.0  United Kingdom
#
#      InvoiceYearMonth  Revenue     MinPurchaseDate  MinPurchaseYearMonth  \
# 0              201012    15.30 2010-12-01 08:26:00                201012
# 1              201012    20.34 2010-12-01 08:26:00                201012
# 2              201012    22.00 2010-12-01 08:26:00                201012
# 3              201012    20.34 2010-12-01 08:26:00                201012
# 4              201012    20.34 2010-12-01 08:26:00                201012
# ..                ...      ...                 ...                   ...
# 495            201110    19.90 2010-12-01 08:34:00                201012
# 496            201110    19.80 2010-12-01 08:34:00                201012
# 497            201110    19.90 2010-12-01 08:34:00                201012
# 498            201110    34.68 2010-12-01 08:34:00                201012
# 499            201110     7.90 2010-12-01 08:34:00                201012
#
#      UserType
# 0         New
# 1         New
# 2         New
# 3         New
# 4         New
# ..        ...
# 495  Existing
# 496  Existing
# 497  Existing
# 498  Existing
# 499  Existing
#
# [500 rows x 13 columns]

# %%
tx_user_type_revenue = tx_uk.groupby(['InvoiceYearMonth','UserType'])['Revenue'].sum().reset_index()

tx_user_type_revenue = tx_user_type_revenue.query("InvoiceYearMonth != 201012 and InvoiceYearMonth != 201112")
tx_user_type_revenue.head(24)
# Out:
#     InvoiceYearMonth  UserType     Revenue
# 1             201101  Existing  195275.510
# 2             201101       New  156705.770
# 3             201102  Existing  220994.630
# 4             201102       New  127859.000
# 5             201103  Existing  296350.030
# 6             201103       New  160567.840
# 7             201104  Existing  268226.660
# 8             201104       New  108517.751
# 9             201105  Existing  434725.860
# 10            201105       New   90847.490
# 11            201106  Existing  408030.060
# 12            201106       New   64479.190
# 13            201107  Existing  407693.610
# 14            201107       New   53453.991
# 15            201108  Existing  421388.930
# 16            201108       New   55619.480
# 17            201109  Existing  640861.901
# 18            201109       New  135667.941
# 19            201110  Existing  648837.600
# 20            201110       New  133940.280
# 21            201111  Existing  838955.910
# 22            201111       New  117153.750

# %%
plt.figure(figsize=(12,6))
plt.plot(tx_user_type_revenue.query("UserType == 'Existing'")['InvoiceYearMonth'].to_numpy(dtype=str),tx_user_type_revenue.query("UserType == 'Existing'")['Revenue'],marker='o')
plt.plot(tx_user_type_revenue.query("UserType == 'New'")['InvoiceYearMonth'].to_numpy(dtype=str),tx_user_type_revenue.query("UserType == 'New'")['Revenue'],marker='o')
plt.grid()

# %%
tx_user_ratio = tx_uk.query("UserType == 'New'").groupby(['InvoiceYearMonth'])['CustomerID'].nunique()/tx_uk.query("UserType == 'Existing'").groupby(['InvoiceYearMonth'])['CustomerID'].nunique() 
tx_user_ratio = tx_user_ratio.reset_index()
tx_user_ratio = tx_user_ratio.dropna()

tx_user_ratio.head()
# Out:
#    InvoiceYearMonth  CustomerID
# 1            201101    1.124224
# 2            201102    0.904000
# 3            201103    0.792233
# 4            201104    0.510166
# 5            201105    0.343793

# %%
plt.figure(figsize=(12,6))
plt.bar(tx_user_ratio.query("InvoiceYearMonth>201101 and InvoiceYearMonth<201112")['InvoiceYearMonth'].to_numpy(dtype=str),tx_user_ratio.query("InvoiceYearMonth>201101 and InvoiceYearMonth<201112")['CustomerID'])
plt.grid()
